# %%
# STEP 1:
#PROBLEM STATEMENT

# %%
# The given dataset contains morphological and environmental characteristics of mushrooms, including features such as cap shape, color, gill properties, stem measurements, spore color, and habitat. Each mushroom instance is labeled as either poisonous (p) or edible (e) in the class column.

# Goal:

# To build a predictive model that can accurately classify mushrooms as edible or poisonous based on their physical attributes.

# Target variable:

# class → Indicates whether a mushroom is poisonous (p) or edible (e).

# %%
# ML MODEL BUILDING STEPS:

# Step 1: Problem Statement|Problem Definition
# Step 2: Data Collection
# Step 3: Data Cleaning
# Step 4: Exploratory Data Analysis (EDA)
# Step 5: Feature Engineering
# Step 6: Model Building
# Step 7: Model Evaluation
# Step 8: Model Deployment

# %%
# ML MODEL BUILDING STEPS EXPLANATION:

# Step 1: Problem Statement|Problem Definition
#     Classification - Telecom Dataset
#     Regression - California Housing
#     Clustering - Retail Dataset

# Step 2: Data Collection
#     Internal DB (SQL, CRM, ERP)
#     Public DB (Kaggle, Sklearn, MLRepo, OpenML)
#     API (Twitter, Google Map)

# Step 3: Data Cleaning
#     Clean data avoid bias or incorrect Model
#     Check for any duplicates, Outliers, NULL Values
#     Treat missing values by applying mean, median, mode
#     For any Outliers - Remove whole value or whole row.
#     Check Interpolate Values - Values between the range.
#     NOTE: Only one DataType should be there in a Row.
#     use df.describe() and check datatypes.
#     use df.info() to check number of int, string, float, etc..
#     NOTE: max>avg (a huge difference) then there is some differences in the datatype such as inches, cms, etc.

# Step 4: Exploratory Data Analysis (EDA)
#     Statisticians use EDA to avoid Overstocking or understocking.
#     E.g., For Retail Sales, Seasonal patterns will be understocked with monthly wise analysis.
#     Summarizes datasets to understand patterns, trends and relationships.
#     PURPOSE:
#     Helps identify useful features and Data issues before Modeling.
#     PROCESS:
#     Summary Statistics> mean, median, mode
#     Visualization:    
#     Histogram, BoxPlot, ScatterPlot, Correlation Heatmaps.

# Step 5: Feature Engineering     
#     Decides which ML model to use.
#     Creating or transforming variables to improve model performance.
#     PURPOSE:
#     Good features, better model even with single algorithm.
#     PROCESS:
#     Encoding categorical variables - One-Hot and Label Encoding
#     Transformation: Log Scaling, Standardization
#     Derived Features: Family size in titani or Day of week from dates.

# Step 6: Model Building
#     Training Algorithms on data to learn platforms.
#     PURPOSE:
#     Provides predictive power for decision making.
#     PROCESS:
#     Split data in to Test-Train sets(sometimes with validation)
#     Choose Algorithm based on problem Type.
#           Regression: Linear Regression, Random Forest
#           Classification: Logistic Regression, SVM, XGBoost.
#           Clustering: KMeans, DBSCAN.
#           Deep Learning: CNN for Images, RNNs for text|time series
#      Examples:
#        Predicting Diabetes - Logistic Regression(Classification)
#        House Prices - Random Forest Regressor
#        Customer Segmentation - KMeans Clustering

# Step 7: Model Evaluation
#      Accessing Model performance using metrics.
#      PURPOSE:
#      Ensures the model generates well and meets business goals.
#      PROCESS:
#      Classification metrics and Accuracy precision.
#      Regression Metrics: MSE, RMSE, MAE, Rsquare, ECP|ROC AUC.
#      Handle imbalanced dataset with weighted metrics.
#      Perform cross-validation for Robustness.
#      Examples:
#         Credit card Fraud (Use ROC AUC Imbalanced)
#         House Price Predictions - Use RMSE (Continuous Target)
#         Spam Detection - Precision and Recall are more important than Accuracy.

# Step 8: Model Deployment

#      Making the trained model available for real world use.
#      PURPOSE:
#      Allows End-users or systems to make predictions in real-time
#      PROCESS:
#      Save Model (Pickle, Joblib, ONNX)
#      Deploy via APIs (Flask, FastAPI)
#      Build Dashboards (Streamlit, PowerBI, Tableau)
#      Monitor Performance (Detect Drift, retain if needed) 
#      E.g., Recommendation system on Netflix or Amazon.
#            Fraud detection models in bank(real-time alerts)
#            Healthcare model integration into Hospital systems


# FINAL SUMMARY:
#      The Data Science Workflow is not just coding. 
#      Its about combining Domain knowledge, understanding Data, Statistical Reasoning 
#      and Engineering skills to deliver real-world impact.

# %%
# Step 1: Problem Statement|Problem Definition

# %%
# Importing neccesary libraries

# %%
import numpy as np # For numerical computations
import pandas as pd # To read DataFrame
import matplotlib.pyplot as plt # For Mathematical computations
import seaborn as sns # Used for Statistical Graphics

# %%
# DATA COLLECTION

# Read the DataFrame with delimiters
# Find number of Rows and Columns
# Check the Datatypes

# %%
# Importing the Dataset

# %%
df=pd.read_csv('secondary_data.csv',sep=";")

# %%
# Ensures that pandas correctly identifies the column boundaries and parses the data into the appropriate columns.

# %%
df.head()
# Out:
#   class  cap-diameter cap-shape cap-surface cap-color does-bruise-or-bleed  \
# 0     p         15.26         x           g         o                    f
# 1     p         16.60         x           g         o                    f
# 2     p         14.07         x           g         o                    f
# 3     p         14.17         f           h         e                    f
# 4     p         14.64         x           h         o                    f
#
#   gill-attachment gill-spacing gill-color  stem-height  stem-width stem-root  \
# 0               e          NaN          w        16.95       17.09         s
# 1               e          NaN          w        17.99       18.19         s
# 2               e          NaN          w        17.80       17.74         s
# 3               e          NaN          w        15.77       15.98         s
# 4               e          NaN          w        16.53       17.20         s
#
# ...

# %%
print(df.shape) # Prints the number of Rows and Columns
# Out:
# (61069, 21)

# %%
pd.set_option('display.max_columns',None) # To modify the display settings for DataFrames
# it instructs pandas to display all columns of a DataFrame when it is printed or displayed, 
# rather than truncating the view and showing an ellipsis (...) for columns exceeding a certain default limit.
df.head()
# Out:
#   class  cap-diameter cap-shape cap-surface cap-color does-bruise-or-bleed  \
# 0     p         15.26         x           g         o                    f
# 1     p         16.60         x           g         o                    f
# 2     p         14.07         x           g         o                    f
# 3     p         14.17         f           h         e                    f
# 4     p         14.64         x           h         o                    f
#
#   gill-attachment gill-spacing gill-color  stem-height  stem-width stem-root  \
# 0               e          NaN          w        16.95       17.09         s
# 1               e          NaN          w        17.99       18.19         s
# 2               e          NaN          w        17.80       17.74         s
# 3               e          NaN          w        15.77       15.98         s
# 4               e          NaN          w        16.53       17.20         s
#
# ...

# %%
# You can also reset this option to its default behavior using pd.reset_option('display.max_columns') if desired.

# %%
# Check the various Datatypes in the given Dataset

# %%
df.dtypes
# Out:
# class                    object
# cap-diameter            float64
# cap-shape                object
# cap-surface              object
# cap-color                object
# does-bruise-or-bleed     object
# gill-attachment          object
# gill-spacing             object
# gill-color               object
# stem-height             float64
# stem-width              float64
# stem-root                object
# stem-surface             object
# stem-color               object
# veil-type                object
# veil-color               object
# has-ring                 object
# ring-type                object
# spore-print-color        object
# habitat                  object
# season                   object
# dtype: object

# %%
# Step 3: Data Cleaning

# %%
df.describe()
# Out:
#        cap-diameter   stem-height    stem-width
# count  61069.000000  61069.000000  61069.000000
# mean       6.733854      6.581538     12.149410
# std        5.264845      3.370017     10.035955
# min        0.380000      0.000000      0.000000
# 25%        3.480000      4.640000      5.210000
# 50%        5.860000      5.950000     10.190000
# 75%        8.540000      7.740000     16.570000
# max       62.340000     33.920000    103.910000

# %%
# df.describe() method is used to generate descriptive statistics of a DataFrame or Series. 
# By default, it focuses on numerical columns, but it can also be used to analyze categorical data.

# %%
df.duplicated().sum() #  is used to count the number of duplicate rows in a DataFrame df
# Out:
# np.int64(146)

# %%
# Drop the duplicates

# %%
df=df.drop_duplicates()
df.head()
# Out:
#   class  cap-diameter cap-shape cap-surface cap-color does-bruise-or-bleed  \
# 0     p         15.26         x           g         o                    f
# 1     p         16.60         x           g         o                    f
# 2     p         14.07         x           g         o                    f
# 3     p         14.17         f           h         e                    f
# 4     p         14.64         x           h         o                    f
#
#   gill-attachment gill-spacing gill-color  stem-height  stem-width stem-root  \
# 0               e          NaN          w        16.95       17.09         s
# 1               e          NaN          w        17.99       18.19         s
# 2               e          NaN          w        17.80       17.74         s
# 3               e          NaN          w        15.77       15.98         s
# 4               e          NaN          w        16.53       17.20         s
#
# ...

# %%
#  Verify duplicates are dropped?

df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum() #  is used to count the number of missing (null or NaN) values in each column of a DataFrame.
# Out:
# class                       0
# cap-diameter                0
# cap-shape                   0
# cap-surface             14120
# cap-color                   0
# does-bruise-or-bleed        0
# gill-attachment          9855
# gill-spacing            25062
# gill-color                  0
# stem-height                 0
# stem-width                  0
# stem-root               51536
# stem-surface            38122
# stem-color                  0
# veil-type               57746
# veil-color              53510
# has-ring                    0
# ring-type                2471
# spore-print-color       54597
# habitat                     0
# season                      0
# dtype: int64

# %%
df.isnull().mean()*100 # calculates the percentage of missing values (NaN or None) in each column of a DataFrame.
# Out:
# class                    0.000000
# cap-diameter             0.000000
# cap-shape                0.000000
# cap-surface             23.176797
# cap-color                0.000000
# does-bruise-or-bleed     0.000000
# gill-attachment         16.176157
# gill-spacing            41.137173
# gill-color               0.000000
# stem-height              0.000000
# stem-width               0.000000
# stem-root               84.592026
# stem-surface            62.574069
# stem-color               0.000000
# veil-type               94.785221
# veil-color              87.832182
# has-ring                 0.000000
# ring-type                4.055939
# spore-print-color       89.616401
# habitat                  0.000000
# season                   0.000000
# dtype: float64

# %%
# Drop columns with a high percentage of missing values and those not label encoded
columns_to_drop = ['stem-root', 'stem-surface', 'veil-type', 'veil-color', 'spore-print-color']
df.drop(columns=columns_to_drop,inplace=True)

# %%
df.columns
# Out:
# Index(['class', 'cap-diameter', 'cap-shape', 'cap-surface', 'cap-color',
#        'does-bruise-or-bleed', 'gill-attachment', 'gill-spacing', 'gill-color',
#        'stem-height', 'stem-width', 'stem-color', 'has-ring', 'ring-type',
#        'habitat', 'season'],
#       dtype='object')

# %%
# Step 4: EDA Exploratory Data Analysis (Histogram, BoxPlot, Scatter Plot, Correlation Heatmap)

# %%
# Step 5: Feature Engineering(One-Hot, Label Encoding):

# %%
# LabelEncoding:

# %%
# Before Label Encoding:

# %%
df.head(3)
# Out:
#   class  cap-diameter cap-shape cap-surface cap-color does-bruise-or-bleed  \
# 0     p         15.26         x           g         o                    f
# 1     p         16.60         x           g         o                    f
# 2     p         14.07         x           g         o                    f
#
#   gill-attachment gill-spacing gill-color  stem-height  stem-width stem-color  \
# 0               e          NaN          w        16.95       17.09          w
# 1               e          NaN          w        17.99       18.19          w
# 2               e          NaN          w        17.80       17.74          w
#
#   has-ring ring-type habitat season
# 0        t         g       d      w
# 1        t         g       d      u
# 2        t         g       d      w

# %%
# Preprocessing: Converts categorical (text) columns into numeric codes using LabelEncoder

# %%
from sklearn import preprocessing
le=preprocessing.LabelEncoder()
columns=['class','cap-shape', 'cap-surface', 'cap-color',
       'does-bruise-or-bleed', 'gill-attachment', 'gill-spacing', 'gill-color',
       'stem-color','has-ring', 'ring-type','habitat', 'season']
for col in columns:
  encoded_values=le.fit_transform(df[col])
  df[col]=encoded_values
df.head()
# After Label Encoding:
# Out:
#    class  cap-diameter  cap-shape  cap-surface  cap-color  \
# 0      1         15.26          6            2          6
# 1      1         16.60          6            2          6
# 2      1         14.07          6            2          6
# 3      1         14.17          2            3          1
# 4      1         14.64          6            3          6
#
#    does-bruise-or-bleed  gill-attachment  gill-spacing  gill-color  \
# 0                     0                2             3          10
# 1                     0                2             3          10
# 2                     0                2             3          10
# 3                     0                2             3          10
# 4                     0                2             3          10
#
#    stem-height  stem-width  stem-color  has-ring  ring-type  habitat  season
# 0        16.95       17.09          11         1          2        0       3
# ...

# %%
# Step 6: Model Building

# %%
# Splitting dataset into Train and Test Sets

# %%
from sklearn.model_selection import train_test_split

X=df.drop('class',axis=1)
y=df['class']

# Train Test Split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %%
# Exploratory Data Analysis (EDA):

# %%
# Plot Correlation Matrix and Confusion Matrix:

# %%
# Correlation matrix
correlation_matrix = df.corr()
# is used to calculate the correlation matrix of a Pandas DataFrame df

# %%
# This matrix provides a comprehensive overview of the linear relationships between all pairs of numerical columns within the DataFrame.

# Used for EDA, Data Visualization, Insights for Model Building, 
# Feature Selection, Identifying Multicollinearity, Understanding Relationships Between Variables

# %%
# df.corr() provides a numerical summary of the pairwise linear dependencies within your data, 
# which is a critical step in various data analysis and machine learning workflows.

# %%
df.corr()
# Out:
#                          class  cap-diameter  cap-shape  cap-surface  \
# class                 1.000000     -0.180027  -0.105437    -0.032740
# cap-diameter         -0.180027      1.000000   0.103308     0.035237
# cap-shape            -0.105437      0.103308   1.000000    -0.045890
# cap-surface          -0.032740      0.035237  -0.045890     1.000000
# cap-color             0.028259      0.040796   0.015317     0.095973
# does-bruise-or-bleed -0.018929      0.178872   0.191394    -0.090562
# gill-attachment      -0.004266      0.011349  -0.151719     0.075541
# gill-spacing         -0.004496      0.090215   0.126792    -0.045307
# gill-color           -0.058439      0.220467   0.114667    -0.028036
# stem-height          -0.118079      0.421718   0.032410     0.045258
# stem-width           -0.195303      0.695047   0.156399     0.062828
# stem-color           -0.091048      0.005678   0.006814     0.123300
# has-ring              0.058480      0.076451   0.035628     0.038241
# ...

# %%
# CORRELATION HEATMAP:

# Correlate Target Variable with which Predictor Variable matches

# There are two types of features in the data:

# Categorical (Strings or some encoded values so it can't be used to write correlation Heatmaps) - 
         # Ordinal(some order like *, **, ***, ..) and Nominal
# Numerical

# %%
# Block is dark - Strong Positive Correlation
# Block is Light - Strong Negative Correlation
# 1 or highly white blocks - represents Strong self correlation

# %%
# CORRELATION HEATMAP:

# A graphical representation of a correlation matrix that uses colors 
# to show the strength and direction of relationships between variables in a dataset

# %%
#  Why we use Correlation Heatmaps:
#  Identify Relationships
#  Detect Multicollinearity
#  Feature Selection
#  Data Exploration

# %%
# Red typically indicates a strong positive correlation, 
# blue a strong negative correlation, 
# and neutral colors show no or weak correlation.

# %%
# These heatmaps are useful for quickly identifying patterns,
# multicollinearity (highly correlated variables), 
# and relationships that may require further investigation.

# %%
# PURPOSE OF A CORRELATION HEATMAP:
# To visualize data density and patterns by using color to represent the magnitude of values in a dataset, 
# making it easier to quickly identify "hot spots" (areas of high concentration) and "cold spots" (areas of low concentration) 
# and to understand complex data without sifting through tables of numbers

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(20, 16))
sns.heatmap(correlation_matrix, square=True, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
# Correlation Heatmap:

k = 3
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(20, 16))
sns.heatmap(correlation_matrix, linecolor="white", vmax=0.8, square=True, annot=True, cmap='viridis', annot_kws={'size':12})
plt.title('Correlation Matrix')
plt.show()

# %%
# Confusion Matrix:

# %%
# To evaluate and summarize the performance of a machine learning classification model 
# by comparing its predicted outputs against the actual, known values in a dataset

# %%
# To evaluate classification model performance by breaking down predictions into true positives, true negatives, false positives, and false negatives, 
# offering a deeper understanding of model errors and biases than accuracy alone. 
# It enables calculation of key metrics like precision and recall, 
# crucial for balancing the costs of different types of errors in real-world applications such as medical diagnosis or fraud detection.

# %%
# Confusion Matrix is used for:

# Detailed Error Analysis (TP, TN, FP, FN)
# Beyond Accuracy - A confusion matrix provides a more granular view of performance. 
# Key Performance Metrics - Precision, Recall(Sensitivity), Specificity, F1 Score.
# Application-Specific Insights - Medical Diagnosis, Fraud Detection.
# Visualizing Performance - Easy to understand how well the model classifies different classes.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(y_test,y_pred):
  cm=confusion_matrix(y_test,y_pred)
  sns.heatmap(cm,annot=True,fmt='d',cmap='Blues')
  plt.xlabel('Predicted')
  plt.ylabel('Actual')
  plt.title("\n Confusion Matrix\n")
  plt.xticks([0.5,1.5],["Edible","Poisonous"])
  plt.yticks([0.5,1.5],["Edible","Poisonous"])

# %%
from sklearn.metrics import classification_report
target_names=['Edible','Poisonous']

# %%
# Classification Report is imported

# For all different classification algorithms, analysis are made

# 1. Decision Tree Classifier
# 2. Random Forest Classifier
# 3. Logistic Regression
# 4. Naive Bayes (GaussianNB)
# 5. KNN

# %%
# Decision Tree Classifier

# %%
# Advantages:
#     Can handle both numerical and categorical data and
#     do not require extensive preprocessing such as Feature scaling or normalization.
#     Decision Trees are robust to outliers in the dataset, 
#     meaning outlier values have minimal impact on overall model performance.
#     They can capture non-linear relationships between input features and the target variable.
#     Decision Trees can handle missing data by making splits based on available information.
#     They are Versatile - supporting both classification and regression problems as well as 
#     multi-output tasks.
#     Trees provide feature importance rankings - aiding in understanding which features drive predictions
#     No need for feature Scaling - They work natively with raw or minimally processed data.
#     Trees have high computationally efficiency and low memory requirements for 
#     small to medium data-sets, supporting real-time usecases.

# %%
# Disadvantages:
#     Prone to overfitting
#     Unstable - Small changes in training data may result in substantially different trees and predictions.
#     Trees tend to be biased toward dominant features or classes.
#     They can struggle with very large datasets
#     Difficulty in finding complex feature interactions.

# %%
# Key methods to prevent overfitting in Decision Tree:
#    Pruning the Tree (Remove unimportant|weak branches post|while training)
#    Limiting maximum Depth (Restricts tree complexity)
#    Setting minimum samples for Split|Leaf (Prevents over-specific branches)
#    Limiting the number of Leaf Nodes (Limits overall tree size)
#    Feature selection and Engineering (Focuses on meaningful features, removes irrelevant ones)
#    Ensemble Methods (Averages out individual tree Errors, reduces variance)
#    Cross-Validation (Ensures Model isn't tuned to random data pecularities)
#    Increasing Training Data (Encourages learning of broader data patterns)
#    Dimensionality reduction (Simplifies the task, especially with high feature counts)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
classifier=DecisionTreeClassifier()
classifier.fit(X_train,y_train)
y_pred=classifier.predict(X_test)
print('\n Decision Tree')
print(classification_report(y_test,y_pred,target_names=target_names))
plot_confusion_matrix(y_test,y_pred)
# Out:
#  Decision Tree
#               precision    recall  f1-score   support
#
#       Edible       1.00      0.99      0.99      6733
#    Poisonous       1.00      1.00      1.00      8498
#
#     accuracy                           1.00     15231
#    macro avg       1.00      1.00      1.00     15231
# weighted avg       1.00      1.00      1.00     15231

# %%
#  Insights for the above Decision Tree Confusion Matrix:

# %%
# Random forest:

# %%
#

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_classifier=RandomForestClassifier(n_estimators=100,random_state=42)
rf_classifier.fit(X_train,y_train)
y_pred=rf_classifier.predict(X_test)
print('\n Random Forest')
print(classification_report(y_test,y_pred,target_names=target_names))
plot_confusion_matrix(y_test,y_pred)
# Out:
#  Random Forest
#               precision    recall  f1-score   support
#
#       Edible       1.00      1.00      1.00      6733
#    Possinous       1.00      1.00      1.00      8498
#
#     accuracy                           1.00     15231
#    macro avg       1.00      1.00      1.00     15231
# weighted avg       1.00      1.00      1.00     15231

# %%
#  Insights for the above Random Forest Confusion Matrix:

# %%
#   What the numbers mean:

#   6730  - True positives for Edible

#   Actual = Edible, predicted = Edible

#   3 - False Negatives for Edible

#   Actual = Edible, Predicted = Poisonous

#   These are Mushrooms that are actually edible but your model predicted as poisonous.

#   0 - False Positives for Edible.

#   Actual = Poisonous, Predicted = Edible

#   Mushrooms that are poisonous but wrongly predicted as Edible(your model didn"t make this mistake at all)

#   8498 - True Positives for Poisonous

#   Actual = Poisonous, Predicted = Poisonous

# %%
#  Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
logreg_classifier = LogisticRegression(max_iter=1000, random_state=42)
logreg_classifier.fit(X_train, y_train)
y_pred = logreg_classifier.predict(X_test)
print('\n Logistic Regression\n')
print(classification_report(y_test, y_pred, target_names=target_names))
plot_confusion_matrix(y_test, y_pred)
# Out:
#  Logistic Regression
#
#               precision    recall  f1-score   support
#
#       Edible       0.60      0.44      0.51      6733
#    Possinous       0.64      0.77      0.70      8498
#
#     accuracy                           0.62     15231
#    macro avg       0.62      0.61      0.60     15231
# weighted avg       0.62      0.62      0.61     15231

# %%
#  Insights for Logistic Regression:

#   What the numbers mean:

#   2981 - Edible

#   6534 - Poisonous

# %%
#  Naives Bayes

# %%
from sklearn.naive_bayes import GaussianNB

# %%
nb_classifier = GaussianNB()
nb_classifier.fit(X_train, y_train)
y_pred = nb_classifier.predict(x_test)
print('\n Naives Bayes')
print(classification_report(y_test, y_pred, target_names=target_names))
plot_confusion_matrix(y_test, y_pred)
# Out:
#  Naives Bayes
#               precision    recall  f1-score   support
#
#       Edible       0.57      0.32      0.41      6733
#    Possinous       0.60      0.81      0.69      8498
#
#     accuracy                           0.59     15231
#    macro avg       0.58      0.56      0.55     15231
# weighted avg       0.59      0.59      0.57     15231

# %%
#  Insights for Naives Bayes:

# %%
#  KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn_classifier = KNeighborsClassifier(n_neighbors=5)
knn_classifier.fit(X_train, y_train)
y_pred = knn_classifier.predict(X_test)
print('\n KNN')
print(classification_report(y_test, y_pred, target_names=target_names))
plot_confusion_matrix(y_test, y_pred)
# Out:
#  KNN
#               precision    recall  f1-score   support
#
#       Edible       1.00      1.00      1.00      6733
#    Possinous       1.00      1.00      1.00      8498
#
#     accuracy                           1.00     15231
#    macro avg       1.00      1.00      1.00     15231
# weighted avg       1.00      1.00      1.00     15231

# %%
#  Insights for KNN:

# %%
# TASK:

# Given is the combined Dataset for Edible and Poisonous Mushroom.
# Seperate the given dataset in to Edible Dataset and Poisonous Dataset and then
# Write seperate Insights using Correlation Heatmap for Edible and Poisonous
